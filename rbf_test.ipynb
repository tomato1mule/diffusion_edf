# %%
import matplotlib.pyplot as plt
import torch

from diffusion_edf.radial_func import GaussianRadialBasisLayerFiniteCutoff
from e3nn.util.jit import script

# %%
layer = torch.jit.script(GaussianRadialBasisLayerFiniteCutoff(num_basis=20, cutoff=1.)).cuda()

# %%
x = torch.linspace(0, 1., 100, requires_grad=True, device='cuda')

# %%
y = layer(x)

# %%
plt.plot(x.detach().cpu(), y.detach().cpu())
