# %%
import math
import torch
from diffusion_edf.dist import *
from diffusion_edf import transforms
import plotly.graph_objs as go
import matplotlib.pyplot as plt

# %%
dtype = torch.float64
device = 'cpu'

eps = 0.1
N=1000
omg_max_prob = 2*math.sqrt(eps)
omg_range = min(omg_max_prob * 4, math.pi)
print(omg_range)
# omg_max_prob_idx = ((omg_max_prob) * N / omg_range)

X = torch.linspace(0, omg_range, N, device=device, dtype=dtype)
Y = igso3_angle(X, eps=eps) * haar_measure_angle(X)
# Out:
# 2.5298221281347035

# %%
plt.plot(X,Y)

# %%
Y.max() / Y[-1]
# Out:
# tensor(56958.6804, dtype=torch.float64)

# %%
Y[-2]
# Out:
# tensor(2.2939e-05, dtype=torch.float64)
